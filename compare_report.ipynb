# %% [markdown]
# # Compare my functions with the ones we made on 14/09/23
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
import pandas as pd


df = pd.read_csv('data/bladedat.txt', sep='\t', names=['r', 'beta', 'c', 'thick'])
df
# Out:
#             r       beta         c       thick
# 0    2.800000  14.500000  5.380000  100.000000
# 1   11.002738  14.432009  5.452480   86.049148
# 2   16.871021  12.545974  5.866004   61.096958
# 3   22.964122   8.892452  6.184511   43.035645
# 4   32.307638   6.382198  6.019962   32.415053
# 5   41.573020   4.673576  5.421891   27.810348
# 6   50.411062   2.886552  4.698220   25.317976
# 7   58.534435   1.207190  3.998680   24.264420
# 8   65.750095  -0.130380  3.398094   24.100682
# 9   71.967492  -1.113925  2.913040   24.100000
# 10  77.185974  -1.861959  2.535947   24.100002
# 11  78.713347  -2.077627  2.430771   24.100001
# 12  80.140217  -2.280079  2.331432   24.100000
# 13  82.708485  -2.644084  2.129069   24.100000
# 14  84.925156  -2.945071  1.903323   24.100000
# 15  86.826486  -3.177329  1.626012   24.100000
# 16  88.448663  -3.357526  1.183599   24.100000
# 17  89.166000  -3.428000  0.600000   24.100000

# %%
from bem import steady_bem

R = 89.17
V_0 = 10.0
omega = 8.032*2*np.pi/60  # 8.032 RPM to rad/s
theta_p = 0
lamda = omega*R/V_0

# R = 89.17
# V_0 = 25.0
# omega = 9.6*2*np.pi/60  # 8.032 RPM to rad/s
# theta_p = 22.975
# lamda = omega*R/V_0

P_out, Thrust, C_P, C_T, C_P_local_list, C_T_local_list = steady_bem(R, V_0, omega, theta_p, lamda, df)


print(f'Thrust = {Thrust:.1f}')
print(f'C_T = {C_T:.3f}')
print(f'P_out = {P_out:.1f}')
print(f'C_P = {C_P:.3f}')
# Out:
# aoa = 62.24773103513306
# C_l = 0.0
# C_d = 0.6
# aoa = 31.365606480545075
# C_l = 0.3137388305341061
# C_d = 0.5403758863121473
# aoa = 20.330150247575794
# C_l = 0.5350491150632382
# C_d = 0.2638061393691161
# aoa = 12.713112227276811
# C_l = 1.1692399717022846
# C_d = 0.12492944640568775
# aoa = 6.7490386295280205
# C_l = 1.2762836574405714
# C_d = 0.01737592334590478
# aoa = 6.173386080204616
# C_l = 1.0825809748897233
# C_d = 0.012678426300645284
# aoa = 6.0010613582374415
# C_l = 1.0648652324983827
# C_d = 0.01143875480931099
# aoa = 6.362432816641418
# C_l = 1.106404140825936
# C_d = 0.011245337537421657
# aoa = 6.869403476727994
# C_l = 1.1637551827304857
# C_d = 0.011552362490856368
# aoa = 7.3213869420618405
# C_l = 1.2147845857587818
# C_d = 0.01189104020654638
# aoa = 7.650906061057668
# C_l = 1.2519872932081648
# C_d = 0.012138180292081663
# aoa = 7.727123178833402
# C_l = 1.2605922064839719
# C_d = 0.01219534266466916
# aoa = 7.786513567822057
# C_l = 1.2672973818071103
# C_d = 0.012239885175866543
# aoa = 7.8602314384911125
# C_l = 1.2756201294056466
# C_d = 0.012295173578868335
# aoa = 7.84829385781498
# C_l = 1.2742723765473114
# C_d = 0.012286220393361235
# aoa = 7.683267552789022
# C_l = 1.2556409067098808
# C_d = 0.012162450664591767
# aoa = 7.129744983218469
# C_l = 1.1931482086053653
# C_d = 0.011747308737413852
# Thrust = 1219.0
# C_T = 0.797
# P_out = 7090.2
# C_P = 0.463

# %%
import matplotlib.pyplot as plt

plt.plot(df['r'], C_P_local_list, '-', label='Original')
plt.xlabel('Radius [m]')
plt.ylabel('Local Power Coefficient')
plt.xlim(0, 90)
plt.ylim(-0.2, 0.6)
plt.grid(linestyle='--', linewidth=0.7, alpha=0.8)
plt.legend()
