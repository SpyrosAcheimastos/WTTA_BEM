# %% [markdown]
# # Compute
#
# flow angle:
#
# $ \tan{\phi} = \frac{ (1-\alpha) V_0 }{ (1+\alpha') \omega r } $
#
#
#
# <br/><br/>
# Not sure about this:
#
# $ \alpha = \phi - (\beta + \theta_p) $
#
#
#
# <br/><br/>
# Normal and tangential load coefficients:
#
# $ C_n = C_l\cos{\phi} + C_d\sin{\phi} $
#
# $ C_t = C_l\sin{\phi} - C_d\cos{\phi} $
#
#
#
#
# <br/><br/>
# Solidity:
#
# $ \sigma(r) = \frac{ c(r) B }{ 2 \pi r} $
#
#
#
# <br/><br/>
# Thrust coefficient:
#
# $C_T = \frac{ (1-\alpha)^2 C_n \sigma }{ \sin^2{\phi} } $
#
#
#
# <br/><br/>
# Prandtl’s tip loss correction:
#
# $ F = \frac{2}{\pi} \cos^{-1}(exp( - \frac{B}{2} \frac{R-r}{r \sin{|\phi|}} )$
#
#
#
# <br/><br/>
# Simple Glauert correction model (Wilson & Walker, $ a_c = 0.2 $):
#
# if $a>a_c$ then:
#
# $ a = 1 + \frac{K}{2} (1-2a_c) - \frac{1}{2} \sqrt{(K(1-2a_c)+2)^2 + 4(Ka_c^2-1)} $
#
# $ K = \frac{4F\sin^2{\phi}}{\sigma C_n}$
#
# else if $a \leq a_c$ then "probably":
#
# $ a = \frac{ 1 + \sqrt{1 - F C_T} }{2}$
#
#
#
# <br/><br/>
# Updating the induction factor:
#
# $ a'^n = \frac{\sigma C_t}{4 F \sin{\phi} \cos{\phi}} (1 + a'^{n-1})$
